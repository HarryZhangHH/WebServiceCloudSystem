# %%
import predict;

# %%
print(load_data());
# Out:
# Data Loaded

# %%
print(preprocess());
# Out:
# Data preprocessed

# %%
print(split());
# Out:
# Train test set splitted

# %%
print(train());
# Out:
#  -- training score: 0.8745318352059925

# %%
print(evaluate());
# Out:
# Precission_score: 0.7704918032786885
# Recall_score: 0.6666666666666666
# F1-score: 0.7148288973384029

# %%
print(predict());
# Out:
# Result predicted

# %%
import visualize;

# %%
print(mutual());
# Out:
# Figure generated

# %%
print("file:///data/feature_mutual_info.png");

# %%
print(corr());
# Out:
# Figure generated

# %%
print("file:///data/feature_corrlation.png");

# %%
print(Pclass());
# Out:
# Figure generated

# %%
print("file:///data/Pclass_relation.png");

# %%
print(Bridge());
# Out:
# Figure generated

# %%
print("file:///data/Bridge_relation.png");

# %%
print(Title());
# Out:
# Figure generated

# %%
print("file:///data/Title_relation.png");

# %%
print(age());
# Out:
# Figure generated

# %%
print("file:///data/age_relation.png");

# %%
print(sex());
# Out:
# Figure generated

# %%
print("file:///data/Sex_relation.png");

# %%
print(fare());
# Out:
# Figure generated

# %%
print("file:///data/bridge_fare.png");

# %%
print(Parch());
# Out:
# Figure generated

# %%
print("file:///data/Parch_relation.png");
